# %% [markdown]
# # SigLIP Baseline

# %%
import dataset as ds
from PIL import Image
import requests
from transformers import AutoProcessor, AutoModel
import torch
from torch.utils.data import DataLoader
from torchvision import transforms as tt
import numpy as np

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
model = AutoModel.from_pretrained("openai/clip-vit-base-patch32").to(device).eval()
processor = AutoProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# /home/ruwen/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
config = model.config.to_dict()

print('** LOAD MODEL ** ')
print(f'\tDevice: {device} ({torch.cuda.device_count()} gpus)')
print(f"\tModel parameters: {np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print(f"\tInput resolution: {config['vision_config']['image_size']}")
print(f"\tContext length: {config['text_config']['max_position_embeddings']}")
print(f"\tVocab size: {config['text_config']['vocab_size']}")
# Out:
# ** LOAD MODEL **
# 	Device: cuda (1 gpus)
# 	Model parameters: 151,277,313
# 	Input resolution: 224
# 	Context length: 77
# 	Vocab size: 49408

# %%
scale = tt.Resize((224, 224))
tensor = tt.ToTensor()
image_composed = tt.transforms.Compose([tensor])

test_set = ds.VisualWSDDataset(mode="test", image_transform=image_composed)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
# if k is 1 gives all instances with the correct prediction as top prediction
# if k > 1 the correct prediction is in the top k predictions of the model
def hit(results, k):
    counter = 0

    for r in results:
        sims = np.absolute(r[1])
        sorted = np.argsort(sims)[:k]

        if r[0] in sorted:
            counter += 1

    return counter / len(results)

def mrr(results):
    sum = 0

    for r in results:
        sims = np.absolute(r[1])
        sorted = np.argsort(sims)
        sum += 1/(np.where(sorted==r[0])[0][0]+1)

    return sum / len(results)

# %%
# if k is 1 gives all instances with the correct prediction as top prediction
# if k > 1 the correct prediction is in the top k predictions of the model
def hit_max(results, k):
    counter = 0

    for r in results:
        sims = np.absolute(r[1])
        sorted = np.argsort(sims)[::-1][:k]

        if r[0] in sorted:
            counter += 1

    return counter / len(results)

def mrr_max(results):
    sum = 0

    for r in results:
        sims = np.absolute(r[1])
        sorted = np.argsort(sims)[::-1]
        sum += 1/(np.where(sorted==r[0])[0][0]+1)

    return sum / len(results)

# %%
cos_distance = torch.nn.CosineSimilarity(dim=1, eps=1e-6)
a = torch.randn(1, 10)
cos_distance(a, a)
# Out:
# tensor([1.])

# %%
def test():
    #correct = 0
    #total = 0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():

        results = []
        correct = 0
        max_correct = 0

        for a,data in enumerate(test_loader):
            images = data["imgs"]
            text = data["label_context"][0]
            correct_idx = data["correct_idx"].item()


            print("----------------------------")
            print("batch: " + str(a+1) + "/" + str(len(test_loader)))
            print("label: " + str(text))
            print("correct index: " + str(correct_idx))

            input_text = processor(text=text, padding="max_length", return_tensors="pt")

            input_imgs = []
            for img in images:
                input_imgs.append(processor(images=img, padding="max_length", return_tensors="pt"))

            img_output = []
            for img in input_imgs:
                img_output.append(model.get_image_features(**img.to(device)))

            text_output = model.get_text_features(**input_text.to(device))

            cos_distance = torch.nn.CosineSimilarity(dim=1, eps=1e-6)

            print("text output shape: " + str(text_output.shape))
            print("img output shape: " + str(img_output[0].shape))
            #print(text_output)
            #print(img_output[0])
            
            sims = []
            for i in range(len(img_output)):
                sims.append(cos_distance(text_output, img_output[i]).cpu().item())
                #print(sims[-1]*100)

            sims = np.absolute(np.array(sims))
            min_idx = np.argmin(sims)
            max_idx = np.argmax(sims)

            print("sims: " + str(sims))
            print("min val: " + str(sims[min_idx]) + " min index: " + str(min_idx))
            print("max val: " + str(sims[max_idx]) + " max index: " + str(max_idx))

            results.append((correct_idx, sims))

            if min_idx == correct_idx:
                correct += 1

            if max_idx == correct_idx:
                max_correct += 1

            #if a > 49:
            #    break

    print(correct)
    print(max_correct)

    return results

# %%
results = test()
# Out:
# ----------------------------
# batch: 1/463
# label: football goal
# correct index: 8
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.25042769 0.25297874 0.25210094 0.25395525 0.25409392 0.25466567
#  0.2522065  0.25364503 0.25360468 0.24799681]
# min val: 0.24799680709838867 min index: 9
# max val: 0.25466567277908325 max index: 5
# ----------------------------
# batch: 2/463
# label: mustard seed
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.2267164  0.22427182 0.2270903  0.22655883 0.22513828 0.22576922
#  0.22583589 0.2246207  0.22539225 0.22162765]
# min val: 0.22162765264511108 min index: 9
# max val: 0.22709029912948608 max index: 2
# ----------------------------
# batch: 3/463
# label: eating seat
# correct index: 5
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.21670344 0.21864194 0.21746886 0.21774925 0.21894921 0.21950743
#  0.21844622 0.21787637 0.21923448 0.2193229 ]
# min val: 0.21670344471931458 min index: 0
# max val: 0.21950742602348328 max index: 5
# ----------------------------
# batch: 4/463
# label: navigate the web
# correct index: 6
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23450831 0.23468183 0.23486695 0.23479486 0.23514697 0.23467407
#  0.23656556 0.23595409 0.23362167 0.23350751]
# min val: 0.23350751399993896 min index: 9
# max val: 0.23656556010246277 max index: 6
# ----------------------------
# batch: 5/463
# label: butterball person
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22411442 0.2248393  0.22274524 0.22350559 0.22275707 0.224924
#  0.22338654 0.22478613 0.224214   0.2242579 ]
# min val: 0.22274523973464966 min index: 2
# max val: 0.2249239981174469 max index: 5
# ----------------------------
# batch: 6/463
# label: neptune statue
# correct index: 6
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23015252 0.23275034 0.23293065 0.23325874 0.22842935 0.23287235
#  0.23334625 0.23143244 0.23205461 0.23322393]
# min val: 0.22842934727668762 min index: 4
# max val: 0.23334625363349915 max index: 6
# ----------------------------
# batch: 7/463
# label: ear tympanum
# correct index: 9
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.25345075 0.25407535 0.25302613 0.24672072 0.25224811 0.25339043
#  0.25296527 0.25614846 0.25376788 0.25194177]
# min val: 0.24672071635723114 min index: 3
# max val: 0.25614845752716064 max index: 7
# ----------------------------
# batch: 8/463
# label: wild thymus
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.2269737  0.22479032 0.22483885 0.22566189 0.22609432 0.22231582
#  0.22819234 0.22145917 0.22213025 0.22891906]
# min val: 0.22145916521549225 min index: 7
# max val: 0.22891905903816223 max index: 9
# ----------------------------
# batch: 9/463
# label: tender embrace
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23155782 0.23085143 0.2314028  0.23148026 0.23095569 0.23136938
#  0.2318455  0.23154292 0.2313696  0.23117027]
# min val: 0.2308514267206192 min index: 1
# max val: 0.23184549808502197 max index: 6
# ----------------------------
# batch: 10/463
# label: mill grinding
# correct index: 9
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23635569 0.23448333 0.23669346 0.23926194 0.23785871 0.2282398
#  0.23750761 0.23808779 0.23931137 0.2395938 ]
# min val: 0.22823980450630188 min index: 5
# max val: 0.23959380388259888 max index: 9
# ----------------------------
# batch: 11/463
# label: winged trumpeter
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22719339 0.22945949 0.22798155 0.22745548 0.23088786 0.23045611
#  0.23085785 0.22848761 0.22929925 0.22964472]
# min val: 0.22719338536262512 min index: 0
# max val: 0.23088786005973816 max index: 4
# ----------------------------
# batch: 12/463
# label: rowing dory
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22775671 0.22694194 0.22892174 0.22738445 0.22951764 0.2286284
#  0.2295084  0.2308839  0.23048434 0.22964302]
# min val: 0.22694194316864014 min index: 1
# max val: 0.2308838963508606 max index: 7
# ----------------------------
# batch: 13/463
# label: formica insect
# correct index: 5
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24647996 0.2429667  0.24710101 0.24869466 0.24674669 0.24661765
#  0.24712175 0.2417573  0.24777871 0.24523605]
# min val: 0.24175730347633362 min index: 7
# max val: 0.24869465827941895 max index: 3
# ----------------------------
# batch: 14/463
# label: trotting appendix
# correct index: 6
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24172619 0.23808166 0.23664942 0.24227932 0.24438207 0.24037424
#  0.24312809 0.2368052  0.24085768 0.24017832]
# min val: 0.23664942383766174 min index: 2
# max val: 0.2443820685148239 max index: 4
# ----------------------------
# batch: 15/463
# label: water alluvion
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24550949 0.24450336 0.24299406 0.2459483  0.24560031 0.24232638
#  0.23900041 0.24446017 0.24621299 0.24585132]
# min val: 0.23900040984153748 min index: 6
# max val: 0.24621298909187317 max index: 8
# ----------------------------
# batch: 16/463
# label: asm launch
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22337006 0.22271636 0.22222157 0.22290415 0.22122586 0.22489646
#  0.22366762 0.22324795 0.22386573 0.2238728 ]
# min val: 0.22122585773468018 min index: 4
# max val: 0.22489646077156067 max index: 5
# ----------------------------
# batch: 17/463
# label: furry cimarron
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22029531 0.22310339 0.22262323 0.2214573  0.22257616 0.22173822
#  0.2229566  0.22163829 0.22116828 0.22244033]
# min val: 0.22029531002044678 min index: 0
# max val: 0.2231033891439438 max index: 1
# ----------------------------
# batch: 18/463
# label: metal steel
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23573235 0.23391849 0.23597658 0.23766875 0.23820043 0.23516291
#  0.23827046 0.23688187 0.23691231 0.23867767]
# min val: 0.23391848802566528 min index: 1
# max val: 0.23867766559123993 max index: 9
# ----------------------------
# batch: 19/463
# label: edible sub
# correct index: 1
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.21154025 0.21259677 0.21285234 0.21213348 0.21221344 0.21004018
#  0.21189496 0.21190016 0.20932922 0.21221818]
# min val: 0.20932921767234802 min index: 8
# max val: 0.212852343916893 max index: 2
# ----------------------------
# batch: 20/463
# label: natural web
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23988277 0.23946473 0.24338742 0.23953612 0.24043462 0.23955432
#  0.24046628 0.23970851 0.23962137 0.24175251]
# min val: 0.23946473002433777 min index: 1
# max val: 0.24338741600513458 max index: 2
# ----------------------------
# batch: 21/463
# label: reflecting glass
# correct index: 9
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.2187894  0.21920413 0.21887811 0.22019407 0.21811667 0.21804789
#  0.21916559 0.21880001 0.21893673 0.21924827]
# min val: 0.2180478870868683 min index: 5
# max val: 0.22019407153129578 max index: 3
# ----------------------------
# batch: 22/463
# label: cardamom seed
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22572154 0.2458342  0.23826107 0.24663042 0.24443309 0.24784303
#  0.23569244 0.24569777 0.24356318 0.24592006]
# min val: 0.225721538066864 min index: 0
# max val: 0.24784302711486816 max index: 5
# ----------------------------
# batch: 23/463
# label: drill training
# correct index: 9
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.21979946 0.21969911 0.21808715 0.22073616 0.21970794 0.22052506
#  0.22004092 0.21721469 0.22023101 0.22025356]
# min val: 0.2172146886587143 min index: 7
# max val: 0.22073616087436676 max index: 3
# ----------------------------
# batch: 24/463
# label: medical anemia
# correct index: 1
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23974518 0.25236079 0.24958198 0.25237474 0.24340518 0.24795255
#  0.24603795 0.24849854 0.24473776 0.25034857]
# min val: 0.23974518477916718 min index: 0
# max val: 0.2523747384548187 max index: 3
# ----------------------------
# batch: 25/463
# label: anapurna peak
# correct index: 8
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23291413 0.23260474 0.23154844 0.23262724 0.23197782 0.23199546
#  0.22892886 0.23212731 0.23221862 0.23220867]
# min val: 0.22892886400222778 min index: 6
# max val: 0.23291413486003876 max index: 0
# ----------------------------
# batch: 26/463
# label: mescal distilled
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24546659 0.24122213 0.25155419 0.254228   0.25225434 0.25303072
#  0.24947299 0.2507734  0.25073421 0.24825238]
# min val: 0.24122212827205658 min index: 1
# max val: 0.25422799587249756 max index: 3
# ----------------------------
# batch: 27/463
# label: flying butterfly
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23745741 0.2340219  0.23408683 0.23448169 0.23452379 0.23429061
#  0.23612449 0.23625642 0.23655486 0.23340501]
# min val: 0.2334050089120865 min index: 9
# max val: 0.23745740950107574 max index: 0
# ----------------------------
# batch: 28/463
# label: ling fish
# correct index: 8
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23183231 0.22993261 0.23199084 0.23261219 0.22874694 0.23247822
#  0.2318666  0.23270476 0.23169166 0.23289707]
# min val: 0.2287469357252121 min index: 4
# max val: 0.2328970730304718 max index: 9
# ----------------------------
# batch: 29/463
# label: personal bag
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22282395 0.21980894 0.21992536 0.22144985 0.22235221 0.22164352
#  0.22140892 0.22287655 0.22270925 0.2204172 ]
# min val: 0.2198089361190796 min index: 1
# max val: 0.22287654876708984 max index: 7
# ----------------------------
# batch: 30/463
# label: tea herb
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22128612 0.2265937  0.21450204 0.2260998  0.22486699 0.22494763
#  0.22367686 0.22485586 0.22771138 0.22653455]
# min val: 0.21450203657150269 min index: 2
# max val: 0.22771137952804565 max index: 8
# ----------------------------
# batch: 31/463
# label: lift surgery
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22096431 0.22074765 0.22073944 0.22012299 0.22230688 0.22220671
#  0.22297555 0.22172926 0.22138567 0.22231954]
# min val: 0.22012299299240112 min index: 3
# max val: 0.22297555208206177 max index: 6
# ----------------------------
# batch: 32/463
# label: neck human
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24465862 0.24599935 0.24558595 0.24586776 0.24589682 0.24584012
#  0.24533856 0.24602146 0.24552691 0.24497366]
# min val: 0.24465861916542053 min index: 0
# max val: 0.24602146446704865 max index: 7
# ----------------------------
# batch: 33/463
# label: planet mercury
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24471229 0.24399257 0.24412799 0.24465507 0.24243912 0.24608397
#  0.24438494 0.24431401 0.24395366 0.24464054]
# min val: 0.2424391210079193 min index: 4
# max val: 0.24608397483825684 max index: 5
# ----------------------------
# batch: 34/463
# label: gin cards
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.20828615 0.20781243 0.209961   0.20973535 0.21017778 0.20814076
#  0.21003681 0.20695952 0.20882612 0.20864964]
# min val: 0.20695951581001282 min index: 7
# max val: 0.21017777919769287 max index: 4
# ----------------------------
# batch: 35/463
# label: cyclist seat
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23273024 0.22883993 0.23139238 0.23195702 0.22957674 0.23151353
#  0.2249632  0.23113674 0.22965823 0.23049647]
# min val: 0.2249632030725479 min index: 6
# max val: 0.23273023962974548 max index: 0
# ----------------------------
# batch: 36/463
# label: retard manoeuver
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23066168 0.2354932  0.23473048 0.23732752 0.23320432 0.23749518
#  0.23730931 0.23505549 0.23510849 0.2358765 ]
# min val: 0.23066167533397675 min index: 0
# max val: 0.23749518394470215 max index: 5
# ----------------------------
# batch: 37/463
# label: terry fabric
# correct index: 1
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22756764 0.22709225 0.22613813 0.22730055 0.22621849 0.22594112
#  0.22675174 0.22472836 0.22200394 0.22872396]
# min val: 0.22200393676757812 min index: 8
# max val: 0.22872395813465118 max index: 9
# ----------------------------
# batch: 38/463
# label: sailing tack
# correct index: 1
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24221262 0.23899765 0.24064443 0.2413788  0.23975325 0.24162823
#  0.24239431 0.24044305 0.23989888 0.23946704]
# min val: 0.2389976531267166 min index: 1
# max val: 0.2423943132162094 max index: 6
# ----------------------------
# batch: 39/463
# label: mew sound
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22357124 0.22504616 0.22356287 0.22426355 0.22450578 0.22274426
#  0.22319347 0.22394174 0.22384086 0.22390018]
# min val: 0.22274425625801086 min index: 5
# max val: 0.22504615783691406 max index: 1
# ----------------------------
# batch: 40/463
# label: golf flag
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24198702 0.24249223 0.2401377  0.24196205 0.23792389 0.24200097
#  0.24177462 0.24280283 0.23946579 0.24190153]
# min val: 0.23792389035224915 min index: 4
# max val: 0.24280282855033875 max index: 7
# ----------------------------
# batch: 41/463
# label: nan river
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22553663 0.22700742 0.22602184 0.2268061  0.22676402 0.22720279
#  0.22737199 0.22754589 0.22682051 0.22419521]
# min val: 0.2241952121257782 min index: 9
# max val: 0.22754588723182678 max index: 7
# ----------------------------
# batch: 42/463
# label: earth globe
# correct index: 8
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23450634 0.23528931 0.23437831 0.2335144  0.2225163  0.23330474
#  0.23699917 0.233152   0.23476493 0.23446997]
# min val: 0.22251629829406738 min index: 4
# max val: 0.23699916899204254 max index: 6
# ----------------------------
# batch: 43/463
# label: mimosa beverage
# correct index: 3
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23216602 0.23146409 0.2303277  0.23118764 0.22814974 0.21626188
#  0.22426531 0.23145373 0.22423616 0.23267367]
# min val: 0.2162618786096573 min index: 5
# max val: 0.23267367482185364 max index: 9
# ----------------------------
# batch: 44/463
# label: liquid mercury
# correct index: 3
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.25064692 0.25016713 0.25042379 0.25077948 0.24908099 0.25029224
#  0.24940574 0.24786246 0.25040421 0.24532071]
# min val: 0.24532070755958557 min index: 9
# max val: 0.25077947974205017 max index: 3
# ----------------------------
# batch: 45/463
# label: thresher fish
# correct index: 0
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23379038 0.22841787 0.23397252 0.23145449 0.2336214  0.23363772
#  0.22614181 0.23436268 0.22903447 0.23281527]
# min val: 0.2261418104171753 min index: 6
# max val: 0.2343626767396927 max index: 7
# ----------------------------
# batch: 46/463
# label: congo tea
# correct index: 2
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.24429579 0.24526554 0.24612342 0.24531364 0.24351677 0.24363154
#  0.23867035 0.24211204 0.24596986 0.24150354]
# min val: 0.23867034912109375 min index: 6
# max val: 0.24612341821193695 max index: 2
# ----------------------------
# batch: 47/463
# label: cancer constellation
# correct index: 6
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.2589913  0.25573781 0.26261753 0.26183391 0.26047477 0.26166266
#  0.2628988  0.26270324 0.26221848 0.2623648 ]
# min val: 0.2557378113269806 min index: 1
# max val: 0.2628988027572632 max index: 6
# ----------------------------
# batch: 48/463
# label: ecstasy feeling
# correct index: 8
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22189531 0.22157463 0.22154561 0.22176872 0.22189075 0.22040087
#  0.22154918 0.2215811  0.22079921 0.22150373]
# min val: 0.220400869846344 min index: 5
# max val: 0.22189530730247498 max index: 0
# ----------------------------
# batch: 49/463
# label: cygnus galaxy
# correct index: 7
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.22962613 0.22694018 0.23031083 0.23026547 0.22913206 0.23020869
#  0.22859827 0.23023957 0.23034459 0.229784  ]
# min val: 0.22694018483161926 min index: 1
# max val: 0.23034459352493286 max index: 8
# ----------------------------
# batch: 50/463
# label: blackcap gull
# correct index: 4
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.21265791 0.21229902 0.21284565 0.21065967 0.21170968 0.21344376
#  0.2120439  0.213451   0.21297076 0.20971423]
# min val: 0.20971423387527466 min index: 9
# max val: 0.21345099806785583 max index: 7
# ----------------------------
# batch: 51/463
# label: frame bones
# correct index: 6
# text output shape: torch.Size([1, 512])
# img output shape: torch.Size([1, 512])
# sims: [0.23826499 0.23789662 0.23937476 0.23883492 0.23701137 0.23895007
#  0.24033189 0.23847128 0.2360929  0.23913231]
# min val: 0.23609289526939392 min index: 8
# max val: 0.24033188819885254 max index: 6
# 6
# 11

# %%
print("hit1: " + str(hit(results, 1)))
print("mrr: " + str(mrr(results)))
# mit absolutbetrag
# mit richtiger Bildgröße
# Out:
# hit1: 0.11764705882352941
# mrr: 0.28078120136943663

# %%
print("hit1: " + str(hit_max(results, 1)))
print("mrr: " + str(mrr_max(results)))
# Out:
# hit1: 0.21568627450980393
# mrr: 0.3932384064737005

# %%
# calcualte MRR
def mrr(results):

    rr = 0

    for r in results:
        correct_idx = r[0]
        sims = r[1]
        sim_correct = sims[correct_idx]
        sim_sort = np.sort(sims)
        new_idx = np.where(sim_sort == sim_correct)
        rr += 1/(new_idx+1)

    return 1/len(results)*mrr

# calculate HIT@1
def hit1(results):
    correct = 0
    for r in results:
        correct_idx = r[0]
        sims = r[1]
        if correct_idx == np.argmin(sims):
            correct += 1

    return correct/len(results)

print(hit1(results))
print(mrr(results))
# Out:
# 0.11764705882352941
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 28
#      25     return correct/len(results)
#      27 print(hit1(results))
# ---> 28 print(mrr(results))
#
# Cell In[37], line 12, in mrr(results)
#      10     sim_sort = np.sort(sims)
#      11     new_idx = np.where(sim_sort == sim_correct)
# ---> 12     rr += 1/(new_idx+1)
#      14 return 1/len(results)*mrr
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

texts = ["a photo of 2 cats", "a photo of 2 dogs"]
# important: we pass `padding=max_length` since the model was trained with this
inputs = processor(text=texts, images=image, padding="max_length", return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

logits_per_image = outputs.logits_per_image
probs = torch.sigmoid(logits_per_image) # these are the probabilities
print(f"{probs[0][0]:.1%} that image 0 is '{texts[0]}'")
# Out:
# 31.9% that image 0 is 'a photo of 2 cats'
